# %%
import pandas as pd

from datetime import datetime
# sys.path.append(os.path.abspath(os.path.join('../src')))  # Adjust as needed

from src.distance_utils import distance
from src.data_load import load_tables, load_artificial_instance
from src.filtering import filter_labors_by_date, filter_labors_by_city, filter_labores
from src.metrics import collect_vt_metrics_range, show_day_report_dayonly, compute_indicators
from src.preprocessing import remap_to_base_date, build_services_map_df, process_group
from src.plotting import plot_weekly_services, plot_daily_services_week
from src.config import *
from src.inst_generation_utils import top_service_days, create_artificial_week

data_path = '../data'
instance = 'inst2'
directorio_df, labors_raw_df, cities_df, duraciones_df, valid_cities = load_tables(data_path,generate_labors=False)

# %% [markdown]
# # Combining alfred code with Alfred name

# %%
labors_raw_df = labors_raw_df.dropna(subset=['address_point'])
labors_raw_df['longitud'] = labors_raw_df['address_point'].apply(lambda x:  x.strip().replace("POINT (", "").replace(")", "").split()[0])
labors_raw_df['latitud'] = labors_raw_df['address_point'].apply(lambda x:  x.strip().replace("POINT (", "").replace(")", "").split()[1])
labors_cleaned = labors_raw_df.dropna(subset=['alfred']).\
                                            drop_duplicates(['alfred','address_point'])\
                                            [['alfred', 'address_point', 'address_id', 'latitud', 'longitud']].sort_values(['latitud', 'longitud'])

for col in ['latitud', 'longitud']:
    labors_cleaned[col] = labors_cleaned[col].astype(float)

# %%
def enhance_directorio_with_alfred_code(directorio_df: pd.DataFrame,
                                        labors_raw_df: pd.DataFrame,
                                        dir_lat_col="latitud", dir_lon_col="longitud",
                                        lab_lat_col="latitud", lab_lon_col="longitud",
                                        alfred_code_col="alfred") -> pd.DataFrame:
    """
    Add 'alfred_code' to directorio_df by matching on exact lat/long with labors_raw_df.
    """

    # Keep only what we need from labors
    labors_sub = labors_raw_df[[lab_lat_col, lab_lon_col, alfred_code_col]].dropna()

    # Merge directly on coordinates
    merged = directorio_df.merge(
        labors_sub.drop_duplicates(),
        left_on=[dir_lat_col, dir_lon_col],
        right_on=[lab_lat_col, lab_lon_col],
        how="left"
    )

    # Clean up duplicate coordinate columns
    merged = merged.drop(columns=[lab_lat_col, lab_lon_col])

    return merged

# %%
labors_cleaned
# Out:
#         alfred                                  address_point  address_id  \
# 83621  69147.0                  POINT (-75.5051041 10.392139)    123522.0
# 5040   14946.0  POINT (-74.79419462825471 10.906019892143393)     56474.0
# 92288  71852.0                 POINT (-74.7938234 10.9313923)    130778.0
# 9        892.0          POINT (-74.80800339999999 11.0228323)     56469.0
# 31001  46486.0                  POINT (-76.5654636 3.3676395)     72449.0
# ...        ...                                            ...         ...
# 78      9478.0          POINT (-75.5644897 6.335345299999999)     14932.0
# 86152  70424.0           POINT (-75.560277 6.340593500000001)    126965.0
# 10450  22162.0   POINT (-75.56360339999999 6.347043299999999)     29508.0
# 23435  26355.0                  POINT (-73.0492968 6.9751816)     35931.0
# 39      6412.0                  POINT (-73.1037471 7.0910492)     12312.0
#
#          latitud   longitud
# 83621  10.392139 -75.505104
# 5040   10.906020 -74.794195
# 92288  10.931392 -74.793823
# 9      11.022832 -74.808003
# 31001   3.367640 -76.565464
# ...          ...        ...
# 78      6.335345 -75.564490
# 86152   6.340594 -75.560277
# 10450   6.347043 -75.563603
# 23435   6.975182 -73.049297
# 39      7.091049 -73.103747
#
# [90 rows x 5 columns]

# %%
enhance_directorio_with_alfred_code(directorio_df, labors_cleaned)
# Out:
#                       ALFRED'S                                  DIRECCION  \
# 0         Cesar Augusto Enciso                         Cl. 44 Sur #72u-25
# 1           Jorge Cortes Rojas                    Calle 39 sur # 72m - 26
# 2        Mauricio Gomez Pachon                         Calle 4b # 8b - 45
# 3              Orlando Jacinto                        Calle 86 # 95d - 03
# 4                 Alberto Mora                           Calle 162 #95-24
# 5          Jhon Fredy Grajales                    Carrera 147a # 142 - 30
# 6                Manuel Romero                    Carrera 93 B # 132 - 14
# 7       Yeisson Beltran Garzon                          Calle 67 # 7 - 20
# 8          Wilson Socha Cantor                      Carrera 18m # 10 - 51
# 9              Javier Barragán                     Carrera 1 #32a -20 sur
# 10           Julio Cesar Parra                      Carrera 46 # 152 - 29
# 11            Iván Darío Pinta                 Calle 96 bis # 11- 68 Este
# 12  José Ricardo Pérez Alarcón                     Calle 133a # 103f - 42
# 13          Ancisar Echavarría                       Calle 130c # 90 - 10
# 14                Omar Fonseca                        Carrera 98 # 2 - 32
# 15               Jhon Zambrano                       Carrera 143 #143b-54
# 16               Luis Bermúdez                      Carrera 8b # 188 - 29
# 17                 Daniel Toro                      Carrera 7b# 134b - 66
# 18             Felipe Fautoque                      Cra. 86b #53 - 22 Sur
# 19               Eliseo Arenas              Carrera 4b este # 29 - 58 sur
# 20               Roberto Amaya                      Calle 57a # 92a - 51S
# 21   Luis Fernando Matabanchoy   Cl 83 # 52D-73 multifamiliares la Posada
# 22         Julio Cesar Panesso                  Calle 82 # 45-90 apto 202
# 23             Juan Diego Mesa         calle 41 sur cra 25 aa 132 int 306
# 24                Jhon Vasquez  Calle 16 # 71-60 barrio Belén las playas
# 25         José Gonzáles Parra          Carrera 75 # 9aa- 11 Interior 201
# 26              Pedro Callejas                         Calle 47# 2bb-115
# 27                 Jaime Yepes                                Cr52#44-10
# 28      Karen Viviana Martínez                         Cra 43c # 20 d 37
# 29        Jaime Enrique Dueñas                         carrera 43a 39a-81
# 30             Aliut Villafañe      Carrera 12c # 57 - 04  La Inmaculada
# 31                 Erik Parejo                     Cra. 1d 1 #2, Cisneros
# 32      Carlos Fuentes Teherán             Calle 22 # 50 - 88 Zaragocilla
# 33             Jairo Caballero                 Calle 110 # 34 - 25 piso 1
# 34               Fabio Otalora                       Manzana 43 . Casa 18
# 35              Jairo Castillo                             Cra. 7r #63-61
# 36          Juan Carlos Pianda  Vía Cristo Rey, Callejón Palmeras Casa 27
# 37               Yuliana Marín                            Calle 72d#8n-14
# 38              Jeyson Caicedo                        Calle 51 # 29a - 47
# 39               Wilson Ospina          Carrera 10a # 7 - 37 San Cristoba
# 40                  Jose Largo       Calle 116 #25 - 96 ciudadela del rio
#
#                                     UBICACION       LOCALIDAD        CIUDAD  \
# 0   https://maps.app.goo.gl/4umgXouHXbeShQXz7          Timiza        Bogotá
# 1       https://goo.gl/maps/nQdfNYAHqiyzhX768          Timiza        Bogotá
# 2       https://goo.gl/maps/DF3fav585mxwcEqD9          Cajica        Cajica
# 3       https://goo.gl/maps/h2ZTa92BKkg5NSHUA        Quirigua        Bogotá
# 4       https://goo.gl/maps/Cy2azZpNRe2tWQRZ6            Suba        Bogotá
# 5       https://goo.gl/maps/EqMaNJZVF6KcMWEm6            Suba        Bogotá
# 6       https://goo.gl/maps/oNCnFwdCSUa4H6hD8            Suba        Bogotá
# 7       https://goo.gl/maps/i9HU3dnkivccKNPP8       Chapinero        Bogotá
# 8       https://goo.gl/maps/gMfLhK6B2eYB95VA7          Soacha        Soacha
# 9       https://goo.gl/maps/n6xRF4i6eBA7o2Z3A          Soacha        Soacha
# 10      https://goo.gl/maps/VBBFq4wihN6m8ezX9         Mazuren        Bogotá
# 11      https://goo.gl/maps/LHMqtvfMq43FR8c18        San Luis     La Calera
# 12  https://maps.app.goo.gl/JTjTTpWGyk93VSNC9            Suba        Bogotá
# 13      https://goo.gl/maps/gPQR2cLrXsb4UQee7            Suba        Bogotá
# 14      https://goo.gl/maps/RAtDhNqpNyga1zFZ6          Tintal        Bogotá
# 15      https://goo.gl/maps/ombaGUa9nyixZGF16            Suba        Bogotá
# 16  https://maps.app.goo.gl/496XpcGrB9vnvxJb6        Verbenal        Bogotá
# 17  https://maps.app.goo.gl/NRtfACMwa4siiUDm9         Usaquen        Bogotá
# 18  https://maps.app.goo.gl/8A1KJU1nomMec1Z57            Bosa        Bogotá
# 19  https://maps.app.goo.gl/MzMJzCfhv5V6YwMx5          Soacha        Bogotá
# 20  https://maps.app.goo.gl/Emzi82gnrEVpfCQy6            Bosa        Bogotá
# 21  https://maps.app.goo.gl/2Rb5JQvUBzxaVHgAA      Santamaria        Itagui
# 22  https://maps.app.goo.gl/CGYBKG3g91p1dp7v5        Manrique      Manrique
# 23  https://maps.app.goo.gl/sNz9PH2y179Wrq467         La mina      Envigado
# 24  https://maps.app.goo.gl/bv2HYxE8Aws4PX9Q9      Las playas         Belen
# 25  https://maps.app.goo.gl/zkcT4dDsGZZvrTJy8  Las margaritas         Belen
# 26  https://maps.app.goo.gl/u5ZGXT2tVGLjQurp7       Altamonte  Buenos Aires
# 27  https://maps.app.goo.gl/LZWJ7kTuerxvy8cW6      Playa rica        Itagui
# 28  https://maps.app.goo.gl/ESXizYeWRyP9QJkU6          Zamora        Zamora
# 29  https://maps.app.goo.gl/WyzQRtT8hBz352h68       San Diego     San diego
# 30  https://maps.app.goo.gl/7qcACCXXbhwt6zz8A         Soledad      B/quilla
# 31  https://maps.app.goo.gl/DyHTJHTCDbxuNiyF6             NaN           NaN
# 32  https://maps.app.goo.gl/D8Dy5d3aj5RooWmo7       Cartagena     Cartagena
# 33      https://goo.gl/maps/1g1GjvSL1ZL4CJh9A   Floridablanca       B/manga
# 34  https://maps.app.goo.gl/AMQwzLYg2NhgpVEL9        samaria2       Pereira
# 35  https://maps.app.goo.gl/rbQodVEGFE93Q6m17             NaN          Cali
# 36      https://goo.gl/maps/B3qB1NpqKrMuz5yv7             NaN          Cali
# 37  https://maps.app.goo.gl/EYkC2kTrKnpQwaer9             NaN          Cali
# 38  https://maps.app.goo.gl/Lv5wqG7AgmkPm8gm9             NaN          Cali
# 39      https://goo.gl/maps/UmWFJK7FsZibXi419             NaN          Cali
# 40  https://maps.app.goo.gl/jpe97KMXfbXj2HtE8             NaN          Cali
#
#             city start_time  end_time   alfred
# 0         BOGOTA   07:00:00  17:00:00      NaN
# 1         BOGOTA   07:00:00  17:00:00      NaN
# 2         BOGOTA   08:00:00  18:00:00      NaN
# 3         BOGOTA   08:00:00  18:00:00      NaN
# 4         BOGOTA   07:00:00  17:00:00      NaN
# 5         BOGOTA   08:00:00  18:00:00  10500.0
# 6         BOGOTA   07:00:00  17:00:00      NaN
# 7         BOGOTA   08:00:00  18:00:00      NaN
# 8         BOGOTA   07:00:00  17:00:00   2331.0
# 9         BOGOTA   08:00:00  18:00:00      NaN
# 10        BOGOTA   08:00:00  18:00:00      NaN
# 11        BOGOTA   07:00:00  17:00:00      NaN
# 12        BOGOTA   08:00:00  18:00:00      NaN
# 13        BOGOTA   07:00:00  17:00:00    211.0
# 14        BOGOTA   08:00:00  18:00:00  10449.0
# 15        BOGOTA   07:00:00  17:00:00      NaN
# 16        BOGOTA   08:00:00  18:00:00      NaN
# 17        BOGOTA   08:00:00  18:00:00  69860.0
# 18        BOGOTA   07:00:00  17:00:00      NaN
# 19        BOGOTA   08:00:00  18:00:00      NaN
# 20        BOGOTA   08:00:00  18:00:00      NaN
# 21      MEDELLIN   07:00:00  17:00:00      NaN
# 22      MEDELLIN   07:00:00  17:00:00      NaN
# 23      MEDELLIN   08:00:00  18:00:00      NaN
# 24      MEDELLIN   08:00:00  18:00:00      NaN
# 25      MEDELLIN   08:00:00  18:00:00      NaN
# 26      MEDELLIN   08:00:00  18:00:00      NaN
# 27      MEDELLIN   07:00:00  17:00:00      NaN
# 28      MEDELLIN   07:00:00  17:00:00      NaN
# 29      MEDELLIN   07:00:00  17:00:00      NaN
# 30  BARRANQUILLA   07:00:00  17:00:00      NaN
# 31  BARRANQUILLA   08:00:00  18:00:00      NaN
# 32     CARTAGENA   08:00:00  18:00:00      NaN
# 33   BUCARAMANGA   07:00:00  17:00:00      NaN
# 34       PEREIRA   07:00:00  17:00:00      NaN
# 35          CALI   07:00:00  17:00:00      NaN
# 36          CALI   07:00:00  17:00:00      NaN
# 37          CALI   08:00:00  18:00:00      NaN
# 38          CALI   07:00:00  17:00:00      NaN
# 39          CALI   08:00:00  18:00:00      NaN
# 40          CALI   08:00:00  18:00:00      NaN

# %% [markdown]
# # Número de servicios por ciudad

# %% [markdown]
# ## Semanal

# %%
plot_weekly_services(labors_raw_df, valid_cities)
# Out:
# /Users/juanbeta/Library/CloudStorage/GoogleDrive-juan.beta98@gmail.com/My Drive/Work/Alfred/Alfred/code/src/plotting.py:355: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   df_unique["week"] = df_unique[date_col].dt.to_period("W").apply(lambda r: r.start_time)
# /Users/juanbeta/Library/CloudStorage/GoogleDrive-juan.beta98@gmail.com/My Drive/Work/Alfred/Alfred/code/src/plotting.py:355: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_unique["week"] = df_unique[date_col].dt.to_period("W").apply(lambda r: r.start_time)
# 📊 La semana con más servicios fue 2023-01-16 con 782.0 servicios en total.

# %% [markdown]
# ## Diario

# %%
# df_dist = df_dist[pd.notna(df_dist['labor_start_date'])] 
plot_daily_services_week(labors_raw_df, valid_cities, start_date='2025-07-07')

# %% [markdown]
# # Semana artificial 08-09-25

# %% [markdown]
# ## Generar instancia artificial

# %%
# labors_filtered_df = filter_invalid_services(labors_raw_df=labors_raw_df)
labors_filtered_df = labors_raw_df

# %%
top7_df = top_service_days(labors_filtered_df, city_col="city", date_col="labor_start_date", 
                           top_n=7, starting_year=2025)
labors_art_df, mapping_df = create_artificial_week(labors_filtered_df, top7_df)

labors_art_df.to_csv(f'{data_path}/data_clean/artif_col_inst/{instance}/labors_{instance}_df.csv',index=False)
mapping_df.to_csv(f'{data_path}/data_clean/artif_col_inst/{instance}/mapping_art_.csv',index=False)

# %% [markdown]
# ## Explorar instancia artificial

# %%
plot_daily_services_week(labors_art_df, valid_cities, start_date='2025-09-08')
